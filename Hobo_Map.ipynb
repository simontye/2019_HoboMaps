# %%
import pandas as pd
import folium

# %%
hobo_map = folium.Map(location=[40.738, -73.98],
                            zoom_start=12,
                            max_zoom=17,
                            detect_retina=True,
                            tiles='http://maps.nypl.org/warper/maps/tile/16200/{z}/{x}/{y}.png',
                            attr='Manhattan. 1958. New York Public Library')

# %%
folium.Marker(location=[40.728104, -73.985914],
    popup='Emergency Shelter, Inc.',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.74911, -73.977642],
    popup='American National Red Cross (New York Chapter)',
    icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.681126, -74.003863],
    #popup='Bethesda Mission, Inc.',
    #icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.721957, -73.992791],
    popup="Bowery Mission and Young Men's Home",
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.745826, -73.982191],
    popup="Boys' Bureau",
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.728982, -73.992276],
    popup='Hebrew Sheltering and Immigrant Aid Society',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.712758, -73.997763],
    popup='Henry Street United Church',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.72532, -73.993368],
    popup='Holy Name Centre for Homeless Men',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.760029, -73.992987],
    popup='Lutheran Metropolitan Inner Mission Society',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.734546, -73.987418],
    popup='Prison Association of New York',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.737795, -73.998199],
    popup="Men's Social Service Center (Salvation Army)",
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.762869, -73.995209],
    popup='Salvation Army (Manhattan Branch)',
    icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.845553, -73.901079],
    #popup='Salvation Army (Bronx Branch)',
    #icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.683529, -73.96564],
    #popup='Salvation Army (Brooklyn Branch)',
    #icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.619167, -74.076444],
    #popup='Salvation Army (Staten Island Branch)',
    #icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.764244, -73.994383],
    popup='Transient Service Bureau (Salvation Army)',
    icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.808709, -73.949848],
    #popup="Colored Men's Hotel (Salvation Army)",
    #icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.721886, -73.992868],
    popup='Memorial Hotel (Salvation Army)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.764244, -73.994383],
    popup='Loewenstein Memorial Cafeteria (Salvation Army)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.700017, -73.988341],
    popup='Loewenstein Memorial Cafeteria (Salvation Army)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.739292, -73.989363],
    popup='Department of Welfare (City of New York)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.737817, -73.976836],
    popup='The Municipal of Loding House',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.725935, -73.990944],
    popup='East Third Street Branch (YMCA)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.73669, -73.973308],
    popup='The Municipal of Loding House (Dock Annex)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.712297, -73.978286],
    popup='Gold Dust Lodge (Salvation Army)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.738636, -73.994511],
    popup='Hobo News',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.744443, -73.981442],
    popup='Bowery News',
    icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.734336, -74.166768],
    #popup='Hobo News',
    #icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.725262, -73.989155],
    popup='Maryhouse (Catholic Worker)',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.738577, -74.001264],
    popup='The New York Colored Mission (Pre-1916)',
    icon=folium.Icon()).add_to(hobo_map)
#folium.Marker(location=[40.81033, -73.940379],
    #popup='The New York Colored Mission (Post-1916)',
    #icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.746866, -73.976906],
    popup='Bowery News',
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.723459, -73.992486],
    popup="Sammy's Bowery Follies Nightclub",
    icon=folium.Icon()).add_to(hobo_map)
folium.Marker(location=[40.720102, -73.990088],
    popup='Public Baths of the City of New York',
    icon=folium.Icon()).add_to(hobo_map)

hobo_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
